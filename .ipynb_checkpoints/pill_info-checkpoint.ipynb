# %%
pill_info = {
    'Acetaminophen': {
        'uses': 'Pain relief, fever reduction',
        'patients': 'Adults and children',
        'precautions': 'Avoid overdose, check other medications for acetaminophen content',
        'body_part': 'General (pain, fever)'
    },
    'Brilinta': {
        'uses': 'Prevention of blood clots',
        'patients': 'Adults with certain heart or blood vessel conditions',
        'precautions': 'Do not stop taking without doctor\'s advice',
        'body_part': 'Blood'
    },
    'Ciprofloxacin': {
        'uses': 'Antibiotic',
        'patients': 'Adults',
        'precautions': 'Avoid prolonged exposure to sunlight, take with plenty of water',
        'body_part': 'General (bacterial infections)'
    },
    'Doxycycline': {
        'uses': 'Antibiotic',
        'patients': 'Adults and children over 8 years old',
        'precautions': 'Take with plenty of water, avoid sunlight exposure',
        'body_part': 'General (bacterial infections)'
    },
    'Entresto': {
        'uses': 'Heart failure treatment',
        'patients': 'Adults',
        'precautions': 'Do not take if allergic to any component, monitor blood pressure',
        'body_part': 'Heart'
    },
    'Farxiga': {
        'uses': 'Type 2 diabetes treatment',
        'patients': 'Adults with type 2 diabetes',
        'precautions': 'Monitor blood sugar levels, drink plenty of fluids',
        'body_part': 'Kidneys, Blood sugar'
    },
    'Gabapentin': {
        'uses': 'Nerve pain treatment, seizures',
        'patients': 'Adults and children',
        'precautions': 'Do not stop taking abruptly, may cause drowsiness',
        'body_part': 'Nerves, Brain'
    },
    'Hydrochlorothiazide': {
        'uses': 'Diuretic',
        'patients': 'Adults with high blood pressure or edema',
        'precautions': 'Monitor blood pressure, take in the morning',
        'body_part': 'Kidneys, Blood pressure'
    },
    'Ibuprofen': {
        'uses': 'Pain relief, anti-inflammatory',
        'patients': 'Adults and children',
        'precautions': 'Avoid overdose, take with food',
        'body_part': 'General (pain, inflammation)'
    },
    'Jardiance': {
        'uses': 'Type 2 diabetes treatment, cardiovascular protection',
        'patients': 'Adults with type 2 diabetes and heart disease risk',
        'precautions': 'Monitor blood sugar, drink plenty of fluids',
        'body_part': 'Kidneys, Heart'
    }
}
